# %%
import astropy.io.fits as fits
import matplotlib.pyplot as plt
import numpy

# %%
model = fits.open('/home/alger/possum/alger/Whiting_Stil/model.fits', mode='denywrite')

# %%
stokes_i = fits.open('/home/alger/possum/alger/Whiting_Stil/ASKAPsim.2011.EXTRAGAL.cont.image.restored.i.cube.fits',
                     mode='denywrite')

# %%
# plt.imshow(model[0].data[0].mean(axis=0))

# %%
plt.figure(figsize=(10, 10))
plt.imshow(numpy.cbrt(model[0].data[0, :, 1000:1000+1000, 1000:1000+1000].mean(axis=0)) ** (1/3))

# %%
plt.figure(figsize=(10, 10))
plt.imshow(stokes_i[0].data[0, :, 1000 * 5500 // 8192:2000 * 5500 // 8192, 1000 * 5500 // 8192:2000 * 5500 // 8192].mean(axis=0))

# %%
model[0].shape
# Out:
# (4, 300, 8192, 8192)
